# %%
from pathlib import Path
import zipfile
import pandas as pd
import yaml
import csv
import os
import xarray as xr
import rioxarray as rxr
import subprocess

# %%
with open('config_chelsea.yaml', 'r') as f:
    config = yaml.safe_load(f)
input_path = config['input_path']
output_dir = config['output_dir']
target_period = config['target_period']
parquet_path=config["final_dataframe_path"]
tsv_path=config["final_dataframe_path_tsv"]

# %%
os.makedirs(output_dir, exist_ok=True)

# %%
command = [
    "wget.exe", 
    "-i", str(input_path), 
    "-P", str(output_dir), 
    "-nc"
]

# %%
try:
    subprocess.run(command, check=True)
    print("Download complete.")

except FileNotFoundError:
    print("ERROR: 'wget' is not recognized.")
    print("Make sure you have installed wget for Windows and added it to your System PATH.")
    
except subprocess.CalledProcessError as e:
    print(f"Wget stopped with an error (Code: {e.returncode}).")
# Out:
# Download complete.

# %%
# !wget -i {input_path} -P {output_dir}
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
with open('config_chelsea.yaml', 'r') as f:
    config = yaml.safe_load(f)

patterns = {}

switches = config['environmental_variables']['include_variables']
names = config['environmental_variables']['variable_names']

for code, is_active in switches.items():
    if is_active:
        nice_name = names.get(code, code)
        patterns[code] = nice_name

        if "bio" in code:
            alt_code = code.replace("bio", "bio10_")
            patterns[alt_code] = nice_name

            number = code.replace("bio", "")
            if len(number) == 1:
                patterns[f"bio0{number}"] = nice_name
                patterns[f"bio10_0{number}"] = nice_name

# %%
output_dir = Path(config['output_dir'])
datasets = []
for file_path in output_dir.glob("*.tif"):
    filename=file_path.name

    if target_period not in filename:
        continue
    found_var_name = None
    for code, nice_name in patterns.items():
        if code in filename:
            found_var_name = nice_name
            break
   
    if found_var_name:
        try:
            da=rxr.open_rasterio(file_path, masked=True)
            da = da.squeeze().drop_vars("band")
            da.name = found_var_name
            datasets.append(da)
        except Exception as e:
            print(f"   ❌ Error loading {filename}: {e}")

# %%
if datasets:
    env_stack = xr.merge(datasets)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10964\2806185203.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   env_stack = xr.merge(datasets)

# %%
with open('config.yaml', 'r') as f:
    config = yaml.safe_load(f)
    data_path=config["output_dir"]
occ_df=pd.read_parquet(data_path)

# %%
target_lons = xr.DataArray(occ_df["Longitude"], dims="points")
target_lats = xr.DataArray(occ_df["Latitude"], dims="points")

# %%
sampled_data = env_stack.sel(
    x=target_lons, 
    y=target_lats, 
    method="nearest", 
    tolerance=0.1
)

# %%
env_df = sampled_data.to_dataframe().drop(columns=["spatial_ref", "x", "y"])

# %%
env_df
# Out:
#         max_temp  annual_precipitation
# points
# 0         3082.0                2377.0
# 1         3081.0                1925.0
# 2         3108.0                1454.0
# 3         3120.0                1472.0
# 4         3143.0                 827.0
# ...          ...                   ...
# 318       3039.0                2757.0
# 319       3139.0                1455.0
# 320       3013.0                1012.0
# 321       3013.0                1012.0
# 322       3013.0                1012.0
#
# [323 rows x 2 columns]

# %%
env_df = env_df.reset_index(drop=True)
occ_df = occ_df.reset_index(drop=True)
env_df.columns = env_df.columns.str.strip()

# %%
final_df = pd.concat([occ_df, env_df], axis=1)
final_df.columns = final_df.columns.str.strip()

# %%
final_df
# Out:
#                              Scientific Name   Kingdom     Class   Latitude  \
# 0    Panthera tigris tigris (Linnaeus, 1758)  Animalia  Mammalia  27.546213
# 1           Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  27.215220
# 2           Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  29.843404
# 3           Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  23.663864
# 4           Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  25.996317
# ..                                       ...       ...       ...        ...
# 318         Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  26.659422
# 319         Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  20.248467
# 320  Panthera tigris tigris (Linnaeus, 1758)  Animalia  Mammalia  40.166700
# 321    Panthera tigris sumatrae Pocock, 1929  Animalia  Mammalia  40.166700
# 322  Panthera tigris tigris (Linnaeus, 1758)  Animalia  Mammalia  40.166700
#
#      Longitude  Coordinate Uncertainty (m) Country Code  Year  Month  \
# 0    84.256294                       250.0           NP  2025   12.0
# 1    84.985470                        30.0           NP  2021    1.0
# 2    78.189916                        30.0           IN  2016    6.0
# 3    81.013351                       250.0           IN  2009    2.0
# 4    76.492310                       250.0           IN  2007    2.0
# ..         ...                         ...          ...   ...    ...
# 318  91.001129                         NaN           IN  2016   12.0
# 319  79.425378                         NaN           IN  2014    5.0
# 320 -83.083300                         NaN           US  1996    9.0
# 321 -83.083300                         NaN           US  1995    2.0
# 322 -83.083300                         NaN           US  1995    2.0
#
#        Basis of Record Occurrence Status  \
# 0    HUMAN_OBSERVATION           PRESENT
# 1    HUMAN_OBSERVATION           PRESENT
# 2    HUMAN_OBSERVATION           PRESENT
# 3    HUMAN_OBSERVATION           PRESENT
# 4    HUMAN_OBSERVATION           PRESENT
# ..                 ...               ...
# 318  HUMAN_OBSERVATION           PRESENT
# 319  HUMAN_OBSERVATION           PRESENT
# 320  HUMAN_OBSERVATION           PRESENT
# 321  HUMAN_OBSERVATION           PRESENT
# 322  HUMAN_OBSERVATION           PRESENT
#
#                                                  Issue  max_temp  \
# 0    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...    3082.0
# 1                                                 None    3081.0
# 2                                                 None    3108.0
# 3    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...    3120.0
# 4    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...    3143.0
# ..                                                 ...       ...
# 318  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...    3039.0
# 319  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...    3139.0
# 320  GEODETIC_DATUM_ASSUMED_WGS84;CONTINENT_DERIVED...    3013.0
# 321  GEODETIC_DATUM_ASSUMED_WGS84;CONTINENT_DERIVED...    3013.0
# 322  GEODETIC_DATUM_ASSUMED_WGS84;CONTINENT_DERIVED...    3013.0
#
#      annual_precipitation
# 0                  2377.0
# 1                  1925.0
# 2                  1454.0
# 3                  1472.0
# 4                   827.0
# ..                    ...
# 318                2757.0
# 319                1455.0
# 320                1012.0
# 321                1012.0
# 322                1012.0
#
# [323 rows x 14 columns]

# %%
final_df["max_temp"] = (final_df["max_temp"] * 0.1) - 273.15
final_df["max_temp"] = final_df["max_temp"].round(2)
final_df['annual_precipitation'] = final_df['annual_precipitation'] * 0.1
final_df["annual_precipitation"] = final_df["annual_precipitation"].round(1)

# %%
final_df.to_parquet(parquet_path)
final_df.to_csv(tsv_path, sep='\t')

# %%
final_df
# Out:
#                              Scientific Name   Kingdom     Class   Latitude  \
# 0    Panthera tigris tigris (Linnaeus, 1758)  Animalia  Mammalia  27.546213
# 1           Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  27.215220
# 2           Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  29.843404
# 3           Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  23.663864
# 4           Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  25.996317
# ..                                       ...       ...       ...        ...
# 318         Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  26.659422
# 319         Panthera tigris (Linnaeus, 1758)  Animalia  Mammalia  20.248467
# 320  Panthera tigris tigris (Linnaeus, 1758)  Animalia  Mammalia  40.166700
# 321    Panthera tigris sumatrae Pocock, 1929  Animalia  Mammalia  40.166700
# 322  Panthera tigris tigris (Linnaeus, 1758)  Animalia  Mammalia  40.166700
#
#      Longitude  Coordinate Uncertainty (m) Country Code  Year  Month  \
# 0    84.256294                       250.0           NP  2025   12.0
# 1    84.985470                        30.0           NP  2021    1.0
# 2    78.189916                        30.0           IN  2016    6.0
# 3    81.013351                       250.0           IN  2009    2.0
# 4    76.492310                       250.0           IN  2007    2.0
# ..         ...                         ...          ...   ...    ...
# 318  91.001129                         NaN           IN  2016   12.0
# 319  79.425378                         NaN           IN  2014    5.0
# 320 -83.083300                         NaN           US  1996    9.0
# 321 -83.083300                         NaN           US  1995    2.0
# 322 -83.083300                         NaN           US  1995    2.0
#
#        Basis of Record Occurrence Status  \
# 0    HUMAN_OBSERVATION           PRESENT
# 1    HUMAN_OBSERVATION           PRESENT
# 2    HUMAN_OBSERVATION           PRESENT
# 3    HUMAN_OBSERVATION           PRESENT
# 4    HUMAN_OBSERVATION           PRESENT
# ..                 ...               ...
# 318  HUMAN_OBSERVATION           PRESENT
# 319  HUMAN_OBSERVATION           PRESENT
# 320  HUMAN_OBSERVATION           PRESENT
# 321  HUMAN_OBSERVATION           PRESENT
# 322  HUMAN_OBSERVATION           PRESENT
#
#                                                  Issue   max_temp  \
# 0    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...  35.049999
# 1                                                 None  34.950001
# 2                                                 None  37.650002
# 3    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...  38.849998
# 4    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...  41.150002
# ..                                                 ...        ...
# 318  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...  30.750000
# 319  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...  40.750000
# 320  GEODETIC_DATUM_ASSUMED_WGS84;CONTINENT_DERIVED...  28.150000
# 321  GEODETIC_DATUM_ASSUMED_WGS84;CONTINENT_DERIVED...  28.150000
# 322  GEODETIC_DATUM_ASSUMED_WGS84;CONTINENT_DERIVED...  28.150000
#
#      annual_precipitation
# 0              237.699997
# 1              192.500000
# 2              145.399994
# 3              147.199997
# 4               82.699997
# ..                    ...
# 318            275.700012
# 319            145.500000
# 320            101.199997
# 321            101.199997
# 322            101.199997
#
# [323 rows x 14 columns]

# %%
n_records=len(final_df)
avg_temp=final_df["max_temp"].mean()
avg_precip=final_df["annual_precipitation"].mean()
year_min = final_df["Year"].min()
year_max = final_df["Year"].max()

# %%
with open("config_chelsea.yaml", "r") as f:
    config = yaml.safe_load(f)
    log_path = Path(config["log_dir"])
    with open(log_path, "w") as log:
        species_name = final_df["Scientific Name"].iloc[0]
        log.write(f"CHELSEA DATA INSPECTION LOG for {species_name}\n")
        log.write("=" * 35 + "\n\n")

        log.write(f"Total records: {n_records}\n")
        log.write(f"Average Max Temperature (°C): {avg_temp}\n")
        log.write(f"Average Annual Precipitation (mm): {avg_precip}\n")
        log.write(f"Year Range: {year_min} - {year_max}\n")
